# %% [markdown]
# <img src=./img/lec02.logo.png>

# %% [markdown]
# <font size=6><b> lec02. 머신러닝_분석프로세스

# %% [markdown]
# # sklearn 패키지 소개
# * ref : https://scikit-learn.org/stable/

# %% [markdown]
# <div class="sk-sidebar-toc">
#               <ul>
#               <li>
#                 <a href="https://scikit-learn.org/stable/" class="sk-toc-active">User Guide</a>
#               </li>
#               <ul>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/supervised_learning.html" class="">1. Supervised learning</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/unsupervised_learning.html" class="">2. Unsupervised learning</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/model_selection.html" class="">3. Model selection and evaluation</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/inspection.html" class="">4. Inspection</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/visualizations.html" class="">5. Visualizations</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/data_transforms.html" class="">6. Dataset transformations</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/datasets.html" class="">7. Dataset loading utilities</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/computing.html" class="">8. Computing with scikit-learn</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/model_persistence.html" class="">9. Model persistence</a>
#                 </li>
#                 <li>
#                   <a href="https://scikit-learn.org/stable/common_pitfalls.html" class="">10. Common pitfalls and recommended practices</a>
#                 </li>
#               </ul>
#               </ul>
#             </div>

# %% [markdown]
# # 주요 API
# * ref : https://scikit-learn.org/stable/modules/classes.html
#
# <pre><font color=red><b>
# * train_test_split()
# * fit()
# * predict()
# * ___score()

# %% [markdown]
# # 학습 데이터셋

# %% [markdown]
# <b>Dataset loading utilities<br>
# <li class="toctree-l2" data-content="▼" style="cursor: pointer; background-color: white;"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html">7.1. Toy datasets</a><ul style="background-color: white;">
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html#boston-house-prices-dataset">7.1.1. Boston house prices dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html#iris-plants-dataset">7.1.2. Iris plants dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset">7.1.3. Diabetes dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html#optical-recognition-of-handwritten-digits-dataset">7.1.4. Optical recognition of handwritten digits dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html#linnerrud-dataset">7.1.5. Linnerrud dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html#wine-recognition-dataset">7.1.6. Wine recognition dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/toy_dataset.html#breast-cancer-wisconsin-diagnostic-dataset">7.1.7. Breast cancer wisconsin (diagnostic) dataset</a></li>
# </ul>
# </li>
# <li class="toctree-l2" data-content="▼" style="cursor: pointer; background-color: white;"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html">7.2. Real world datasets</a><ul style="background-color: white;">
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html#the-olivetti-faces-dataset">7.2.1. The Olivetti faces dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html#the-20-newsgroups-text-dataset">7.2.2. The 20 newsgroups text dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html#the-labeled-faces-in-the-wild-face-recognition-dataset">7.2.3. The Labeled Faces in the Wild face recognition dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html#forest-covertypes">7.2.4. Forest covertypes</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html#rcv1-dataset">7.2.5. RCV1 dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html#kddcup-99-dataset">7.2.6. Kddcup 99 dataset</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset">7.2.7. California Housing dataset</a></li>
# </ul>
# </li>
# <li class="toctree-l2" data-content="▼" style="cursor: pointer; background-color: white;"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/sample_generators.html">7.3. Generated datasets</a><ul style="background-color: white;">
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/sample_generators.html#generators-for-classification-and-clustering">7.3.1. Generators for classification and clustering</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/sample_generators.html#generators-for-regression">7.3.2. Generators for regression</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/sample_generators.html#generators-for-manifold-learning">7.3.3. Generators for manifold learning</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/sample_generators.html#generators-for-decomposition">7.3.4. Generators for decomposition</a></li>
# </ul>
# </li>
# <li class="toctree-l2" data-content="▼" style="cursor: pointer; background-color: white;"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/loading_other_datasets.html">7.4. Loading other datasets</a><ul style="background-color: white;">
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/loading_other_datasets.html#sample-images">7.4.1. Sample images</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/loading_other_datasets.html#datasets-in-svmlight-libsvm-format">7.4.2. Datasets in svmlight / libsvm format</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/loading_other_datasets.html#downloading-datasets-from-the-openml-org-repository">7.4.3. Downloading datasets from the openml.org repository</a></li>
# <li class="toctree-l3"><a class="reference internal" href="https://scikit-learn.org/stable/datasets/loading_other_datasets.html#loading-from-external-datasets">7.4.4. Loading from external datasets</a></li>
# </ul>
# </li>
# </ul>
# </li>

# %% [markdown]
#  <img src="https://scikit-learn.org/stable/_static/ml_map.png">

# %% [markdown]
# # Machine Learning 프로세스

# %% [markdown]
# <pre><font color=red><b>
# 4.1. Data Load
# 4.2. EDA (Exploratory Data Analysis) 탐색적 데이터 분석
# 4.3. Feature Engineering
# 4.4. 모델 선정(Model Selection)
# 4.5. 모델 학습 및 예측(Train & Predict)
# 4.6. 모델 검증 및 평가 (Validation & Evaluation)
# 4.7. 하이퍼파미터 튜닝(Hyper-parameter optimization)
# 4.8. 모델 저장 및 배포(Model Save & Deployment)

# %% [markdown]
# ----
# ## Data Load
# * df.info() = df.shape + * df.isna().sum()
# * df.head()
# * df.index, df.columns, df[컬럼].values

# %% [markdown]
# ----
# ## EDA (Exploratory Data Analysis) 탐색적 데이터 분석
# * 데이터 분석
# * 차트 시각화(Visualization)

# %% [markdown]
# ----
# ## Feature Engineering
# * 전처리(Preprocessing)
# * 가공 (Engineering)

# %% [markdown]
# ### 결측 데이터(Missing Values) 보간,대체,삭제
# * 데이터가 NaN일 때 그대로 날려버린다 (complete drop)
# * 데이터가 없는 최소의 개수와 같이 규칙을 정해서 날려버린다
# * 데이터가 거의 없는 feature는 feature 자체를 날려버린다
# * 최빈값, 평균값으로 NaN을 채워버린다
# * SMOTE, KNN 같은 모델 학습 후 예측 데이터를 사용해 근사한 값으로 채운다 (가장 과학적인 방법)

# %% [markdown]
# ### 타입 변환(Type Casting)

# %% [markdown]
# ### 이상치(Outlier , Anomaly Detection)

# %% [markdown]
# ### 범주형 변수 categorical data 처리
# * 라벨인코딩(Label Encoding)
# * 원핫인코딩(One-hot Encoding)
# * 범주화(Bining)

# %% [markdown]
# > <font size=4><b>(1) 라벨인코딩(Label Encoding)
# > * n개의 범주형 데이터를 0부터 n-1까지의 연속적 수치 데이터로 표현

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# > <font size=4><b>(2) 원핫인코딩(One-hot Encoding)
# > * 집합의 크기를 벡터의 차원으로 하고, 표현하고 싶은 단어의 인덱스에 1의 값을 부여하고, 다른 인덱스에는 0을 부여하는 벡터 표현 방식
# > *  데이터프레임에서 object 타입으로 되어있는 변수는 dummy 변수화
# > * <font color=red><b> 판다스의 시리즈가 아닌 numpy 행렬을 입력해야함 → df['컬럼'].values
# > * <font color=red><b> 벡터 입력을 허용하지 않음 → reshape(-1,1)을 이용해 Matrix로 변환  (N,) → (N,1)

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# > <font size=4><b>(3) 범주화(Bining)
# > * 연속형 데이터를 구간으로 나누어 범주화하는 방법

# %% [markdown]
# ### 스케일링(Scaling)
# * 데이터의 값이 너무 크거나 작아 변수의 영향이 제대로 반영되지 않을 경우, 알고리즘의 계산 과정에서 0으로 수렴하거나 값이 너무 커져버리는 경우 값의
# * StandardScaler()
# * MinMaxScaler()
# * RobustScaler()

# %% [markdown]
# ------
# ## 모델 선정(Model Selection)
# <pre><font color=red><b>
# * 지도학습(Supervised Learning)
#     * 회귀(Regression)
#     * 분류(Classigication)
#
# * 비지도학습(Unsupervised Learning)
#      *군집(Clustering)

# %% [markdown]
# ----
# ## 모델 학습 및 예측(Train & Predict)
# <pre><font color=red><b>
# * model.fit(X_train,y_train)
# * y_pred = model.predict(X-test
# * model.score(y_test, y_pred)

# %% [markdown]
# ----
# ## 모델 검증 및 평가 (Validation & Evaluation)

# %% [markdown]
# ----
# ## 하이퍼파미터 튜닝(Hyper-parameter optimization)

# %% [markdown]
# ----
# ## 모델 저장 및 배포(Model Save & Deployment)
